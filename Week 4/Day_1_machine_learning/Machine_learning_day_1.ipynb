# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

marketing_df = pd.read_csv('Data_Marketing_Customer_Analysis_Round3.csv')

# %%
sns.heatmap(numerical_df.corr(), annot = True)
# Out:
# <AxesSubplot:>

# %%
categorical_df = marketing_df.select_dtypes(include=[object])
categorical_df
# Out:
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# 10684      central       no   premium  bachelor           1/19/11   jan
# 10685   north west       no     basic   college            1/6/11   jan
# 10686      central       no  extended  bachelor            2/6/11   feb
# 10687  west region       no   premium   college           2/13/11   feb
# 10688      central       no     basic  bachelor            1/8/11   jan
#
#       employment_status gender location_code marital_status     policy_type  \
# ...

# %%
categorical_df.head()
# Out:
#         region response  coverage education effective_to_date month  \
# 0      central       no     basic   college           2/18/11   feb
# 1  west region       no     basic   college           1/18/11   jan
# 2         east       no     basic  bachelor           2/10/11   feb
# 3   north west      yes  extended   college           1/11/11   jan
# 4   north west       no   premium  bachelor           1/17/11   jan
#
#   employment_status gender location_code marital_status     policy_type  \
# 0          employed      m      suburban        married  corporate auto
# 1        unemployed      f      suburban         single   personal auto
# 2          employed      m      suburban         single   personal auto
# 3          employed      m      suburban         single  corporate auto
# 4     medical leave      f      suburban        married   personal auto
#
#          policy renew_offer_type sales_channel  vehicle_class vehicle_size
# ...

# %%
categorical_df.drop(columns=['effective_to_date', 'month'])
# Out:
#        region response  coverage education  employment_status gender  \
# 0           0       no         0   college                  1      m
# 1           3       no         0   college                  4      f
# 2           1       no         0  bachelor                  1      m
# 3           2      yes         1   college                  1      m
# 4           2       no         2  bachelor                  2      f
# ...       ...      ...       ...       ...                ...    ...
# 10684       0       no         2  bachelor                  4      f
# 10685       2       no         0   college                  1      f
# 10686       0       no         1  bachelor                  1      f
# 10687       3       no         2   college                  1      f
# 10688       0       no         0  bachelor                  4      m
#
#        location_code  marital_status     policy_type        policy  \
# 0                  1               1  corporate auto  corporate l3
# ...

# %%
pd.get_dummies((categorical_df), columns = ['response', 'education', 'location_code','month', 'gender'], drop_first=True)
# Out:
#        region  coverage effective_to_date  employment_status  marital_status  \
# 0           0         0           2/18/11                  1               1
# 1           3         0           1/18/11                  4               2
# 2           1         0           2/10/11                  1               2
# 3           2         1           1/11/11                  1               2
# 4           2         2           1/17/11                  2               1
# ...       ...       ...               ...                ...             ...
# 10684       0         2           1/19/11                  4               1
# 10685       2         0            1/6/11                  1               1
# 10686       0         1            2/6/11                  1               1
# 10687       3         2           2/13/11                  1               0
# 10688       0         0            1/8/11                  4               2
#
# ...

# %%
from sklearn import preprocessing
le = preprocessing.LabelEncoder()
categorical_df['coverage'] = le.fit_transform(categorical_df['coverage'])
categorical_df['renew_offer_type'] = le.fit_transform(categorical_df['renew_offer_type'])
categorical_df['vehicle_class'] = le.fit_transform(categorical_df['vehicle_class'])
categorical_df['vehicle_size'] = le.fit_transform(categorical_df['vehicle_size'])
categorical_df['education'] = le.fit_transform(categorical_df['education'])
categorical_df['policy'] = le.fit_transform(categorical_df['policy'])

pd.get_dummies((categorical_df), columns = ['response','location_code', 'region', 'marital_status', 'sales_channel', 'location_code', 'employment_status','policy_type', 'gender', ], drop_first=True)

categorical_df.drop(columns=['effective_to_date', 'month'])
# Out:
#        region response  coverage  education  employment_status  gender  \
# 0           0       no         0          1                  1       1
# 1           3       no         0          1                  4       0
# 2           1       no         0          0                  1       1
# 3           2      yes         1          1                  1       1
# 4           2       no         2          0                  2       0
# ...       ...      ...       ...        ...                ...     ...
# 10684       0       no         2          0                  4       0
# 10685       2       no         0          1                  1       0
# 10686       0       no         1          0                  1       0
# 10687       3       no         2          1                  1       0
# 10688       0       no         0          0                  4       1
#
#        location_code  marital_status  policy_type  policy  renew_offer_type  \
# ...

# %%
numerical = marketing_df.select_dtypes(include=[np.number])
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()

numerical_df[['income']] = scaler.fit_transform(numerical_df[['income']])
numerical_df
# Out:
#        customer_lifetime_value    income  monthly_premium_auto  \
# 0                         4809  0.422396                    61
# 1                         2228  0.914158                    64
# 2                        14947  0.134550                   100
# 3                        22332  0.434059                    97
# 4                         9025  0.151628                   117
# ...                        ...       ...                   ...
# 10684                    15563  0.572623                   253
# 10685                     5259  0.568231                    65
# 10686                    23893  0.331317                   201
# 10687                    11971  0.602130                   158
# 10688                     6857  0.654907                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
sns.histplot(data = numerical_df, x = 'income', kde = True)
# Out:
# <AxesSubplot:xlabel='income', ylabel='Count'>

# %%
varB = pd.DataFrame(numerical_df['customer_lifetime_value'])
from numpy import asarray
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
scaled = scaler.fit_transform(varB)
plt.hist(scaled, bins=25)
plt.show()
