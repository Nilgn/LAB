# %% [markdown]
# # Onur's Vacation

# %% [markdown]
# <div class="alert alert-success">This notebook explains Onur's holiday adventures in *Stari Grad*.</div>

# %%
x ='His name is Onur and is 35 years old.'

print(x)
# Out:
# His name is Onur and he is 35 years old.

# %% [markdown]
# ![07A52E94-0557-4742-8EBF-147508EF3203_1_105_c.jpeg](attachment:07A52E94-0557-4742-8EBF-147508EF3203_1_105_c.jpeg)

# %% [markdown]
# <font color=blue>Onur is in *Stari Grad* and seems sooo happpyyyy!!!</font>

# %% [markdown]
# ![Screenshot%202023-01-09%20at%2016.31.15.png](attachment:Screenshot%202023-01-09%20at%2016.31.15.png)

# %% [markdown]
# #### The top 3 things that Onur likes to do at this destination.
# - Drinking
# - Swimming
# - And again drinking

# %% [markdown]
# https://www.youtube.com/watch?v=0Vm8oL6dhLk

# %%
from IPython.display import HTML

HTML("""
<div align="center">
    <iframe width="560" height="315" 
    src="https://www.youtube.com/embed/EPjR2O24yM4"
    </iframe>
</div>
""")
# Out:
# <div align="center">
#     <iframe width="560" height="315"
#     src="https://www.youtube.com/embed/EPjR2O24yM4"
#     </iframe>
# </div>
