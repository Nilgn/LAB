# %%
import numpy as np
import pandas as pd

def loading_data():
    file1 = pd.read_csv('file1.csv')
    file1.rename(columns = {'ST':'State'}, inplace = True)
    file1.rename(columns = {'GENDER':'Gender'}, inplace = True)
    file2 = pd.read_csv('file2.csv')
    file2.rename(columns = {'ST':'State'}, inplace = True)
    file2.rename(columns = {'GENDER':'Gender'}, inplace = True)
    file3 = pd.read_csv('file3.csv')
    return pd.concat([file1, file2, file3], axis = 0)

# %%
customer_data = loading_data()

# %%
customer_data
# Out:
#      Customer       State Gender             Education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      Customer Lifetime Value   Income  Monthly Premium Auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def lower_case_column_names(customer_data):
    customer_data.columns=[i.lower() for i in customer_data.columns]
    return customer_data

# %%
customer_data = lower_case_column_names(customer_data)

# %%
customer_data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def remove_duplicates(customer_data):
    return customer_data.drop_duplicates()

# %%
customer_data = remove_duplicates(customer_data)

# %%
customer_data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 7065  LA72316  California      M              Bachelor
# 7066  PK87824  California      F               College
# 7067  TD14365  California      M              Bachelor
# 7068  UP19263  California      M               College
# 7069  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
def remove_nonunique_customer_ids(customer_data):
    return customer_data.drop_duplicates(subset=['customer'])

# %%
customer_data = remove_nonunique_customer_ids(customer_data)

# %%
customer_data = customer_data.reset_index(drop = True)
customer_data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9052  LA72316  California      M              Bachelor
# 9053  PK87824  California      F               College
# 9054  TD14365  California      M              Bachelor
# 9055  UP19263  California      M               College
# 9056  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                 697953.59%      0.0                  94.0
# 2                1288743.17%  48767.0                 108.0
# ...

# %%
customer_data['customer lifetime value'] = customer_data['customer lifetime value'].str.replace('%','')

# %%
customer_data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9052  LA72316  California      M              Bachelor
# 9053  PK87824  California      F               College
# 9054  TD14365  California      M              Bachelor
# 9055  UP19263  California      M               College
# 9056  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
customer_data = customer_data.reset_index(drop = True) 
customer_data
# Out:
#      customer       state gender             education  \
# 0     RB50392  Washington    NaN                Master
# 1     QZ44356     Arizona      F              Bachelor
# 2     AI49188      Nevada      F              Bachelor
# 3     WW63253  California      M              Bachelor
# 4     GA49547  Washington      M  High School or Below
# ...       ...         ...    ...                   ...
# 9052  LA72316  California      M              Bachelor
# 9053  PK87824  California      F               College
# 9054  TD14365  California      M              Bachelor
# 9055  UP19263  California      M               College
# 9056  Y167826  California      M               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
customer.loc[:,["number of open complaints"]] = pd.to_numeric(customer_data['number of open complaints"]])
# Out:
#   File "/var/folders/8w/ffbmg1l958n0dtswfb_xw04c0000gn/T/ipykernel_7263/3896860499.py", line 1
#     customer.loc[:,["number of open complaints"]] = pd.to_numeric(customer_data['number of open complaints"]])
#                                                                                                               ^
# SyntaxError: EOL while scanning string literal

# %%
def truncate_customer_lifetime_value(customer_data):
    customer_data['customer lifetime value'] = customer_data['customer lifetime value'].astype(str).astype(float)

# %%
customer_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9057 entries, 0 to 9056
# Data columns (total 11 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   customer                   9056 non-null   object
#  1   state                      9056 non-null   object
#  2   gender                     8934 non-null   object
#  3   education                  9056 non-null   object
#  4   customer lifetime value    2057 non-null   object
#  5   income                     9056 non-null   float64
#  6   monthly premium auto       9056 non-null   float64
#  7   number of open complaints  9056 non-null   object
#  8   policy type                9056 non-null   object
#  9   vehicle class              9056 non-null   object
#  10  total claim amount         9056 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 778.5+ KB

# %%
customer_data['number of open complaints'].value_counts()
# Out:
# 0         5567
# 1/0/00    1623
# 1          754
# 2          281
# 1/1/00     247
# 3          228
# 4          119
# 1/2/00      93
# 1/3/00      60
# 5           43
# 1/4/00      29
# 1/5/00      12
# Name: number of open complaints, dtype: int64

# %%
customer_data['number of open complaints'][0][2]
# Out:
# '0'

# %%
customer_data['number of open complaints']= [x[2] if type(x) == str else x for x in customer_data['number of open complaints']]

# %%
customer_data['number of open complaints'].value_counts()
# Out:
# 0    5567
# 0    1623
# 1     754
# 2     281
# 1     247
# 3     228
# 4     119
# 2      93
# 3      60
# 5      43
# 4      29
# 5      12
# Name: number of open complaints, dtype: int64

# %%
customer_data.loc [:, 'gender'] = np.where(customer_data.loc[:, 'gender'] == 'M', 'Male', customer_data.loc[:, 'gender'])

customer_data.loc [:, 'gender'] = np.where(customer_data.loc[:, 'gender'] == 'F', 'Female', customer_data.loc[:, 'gender'])
customer_data.loc [:, 'gender'] = np.where(customer_data.loc[:, 'gender'] == 'female', 'Female', customer_data.loc[:, 'gender'])

customer_data.state = customer_data.state.apply(lambda x: 'Arizona' if x == 'AZ' else x)
customer_data.state = customer_data.state.apply(lambda x: 'Washington' if x == 'WA' else x)
customer_data
# Out:
#      customer       state  gender             education  \
# 0     RB50392  Washington     NaN                Master
# 1     QZ44356     Arizona  Female              Bachelor
# 2     AI49188      Nevada  Female              Bachelor
# 3     WW63253  California    Male              Bachelor
# 4     GA49547  Washington    Male  High School or Below
# ...       ...         ...     ...                   ...
# 9052  LA72316  California    Male              Bachelor
# 9053  PK87824  California  Female               College
# 9054  TD14365  California    Male              Bachelor
# 9055  UP19263  California    Male               College
# 9056  Y167826  California    Male               College
#
#      customer lifetime value   income  monthly premium auto  \
# 0                        NaN      0.0                1000.0
# 1                  697953.59      0.0                  94.0
# 2                 1288743.17  48767.0                 108.0
# ...

# %%
customer_data['gender'].value_counts().reset_index()
# Out:
#     index  gender
# 0  Female    4548
# 1    Male    4369
# 2   Femal      17

# %%
customer_data['state'].value_counts().reset_index()
# Out:
#         index  state
# 0  California   3030
# 1      Oregon   2601
# 2     Arizona   1703
# 3      Nevada    882
# 4  Washington    720
# 5        Cali    120

# %%
a = customer_data['income'].mean()
customer_data.income = customer_data.income.apply(lambda x: a if x == 0.0  else x)
#fullna ile yapilacak bunlar

# %%
customer_data
# Out:
#      customer       state  gender             education  \
# 0     RB50392  Washington     NaN                Master
# 1     QZ44356     Arizona  Female              Bachelor
# 2     AI49188      Nevada  Female              Bachelor
# 3     WW63253  California    Male              Bachelor
# 4     GA49547  Washington    Male  High School or Below
# ...       ...         ...     ...                   ...
# 9052  LA72316  California    Male              Bachelor
# 9053  PK87824  California  Female               College
# 9054  TD14365  California    Male              Bachelor
# 9055  UP19263  California    Male               College
# 9056  Y167826  California    Male               College
#
#      customer lifetime value        income  monthly premium auto  \
# 0                        NaN  37710.365172                1000.0
# 1                  697953.59  37710.365172                  94.0
# 2                 1288743.17  48767.000000                 108.0
# ...

# %%
customer_data['customer lifetime value'] = pd.to_numeric(customer_data['customer lifetime value'], errors = 'coerce')
customer_data['customer lifetime value'] = customer_data['customer lifetime value'].fillna(0)
customer_data['customer lifetime value'] = customer_data['customer lifetime value'].astype('int')
customer_data
# Out:
#      customer       state  gender             education  \
# 0     RB50392  Washington     NaN                Master
# 1     QZ44356     Arizona  Female              Bachelor
# 2     AI49188      Nevada  Female              Bachelor
# 3     WW63253  California    Male              Bachelor
# 4     GA49547  Washington    Male  High School or Below
# ...       ...         ...     ...                   ...
# 9052  LA72316  California    Male              Bachelor
# 9053  PK87824  California  Female               College
# 9054  TD14365  California    Male              Bachelor
# 9055  UP19263  California    Male               College
# 9056  Y167826  California    Male               College
#
#       customer lifetime value        income  monthly premium auto  \
# 0                           0  37710.365172                1000.0
# 1                      697953  37710.365172                  94.0
# 2                     1288743  48767.000000                 108.0
# ...

# %%
import numpy as np
customer_data.loc[:, 'gender'] = np.where(customer_data.loc[:,'gender'].isnull(), 'No gender', customer_data.loc[:,'gender'])

# %%
customer_data
# Out:
#      customer       state     gender             education  \
# 0     RB50392  Washington  No gender                Master
# 1     QZ44356     Arizona     Female              Bachelor
# 2     AI49188      Nevada     Female              Bachelor
# 3     WW63253  California       Male              Bachelor
# 4     GA49547  Washington       Male  High School or Below
# ...       ...         ...        ...                   ...
# 9052  LA72316  California       Male              Bachelor
# 9053  PK87824  California     Female               College
# 9054  TD14365  California       Male              Bachelor
# 9055  UP19263  California       Male               College
# 9056  Y167826  California       Male               College
#
#       customer lifetime value        income  monthly premium auto  \
# 0                           0  37710.365172                1000.0
# 1                      697953  37710.365172                  94.0
# ...

# %% [markdown]
# ##Optional

# %%
customer_data['state'] = customer_data['state'].astype(str).str.replace('California', 'West Region')
customer_data['state'] = customer_data['state'].astype(str).str.replace('Oregeon', 'North West Region')
customer_data['state'] = customer_data['state'].astype(str).str.replace('Washington', 'East Region')
customer_data['state'] = customer_data['state'].astype(str).str.replace('Arizona', 'Central Region')
customer_data['state'] = customer_data['state'].astype(str).str.replace('Nevada', 'Central Region')

# %%
customer_data
# Out:
#      customer           state     gender             education  \
# 0     RB50392     East Region  No gender                Master
# 1     QZ44356  Central Region     Female              Bachelor
# 2     AI49188  Central Region     Female              Bachelor
# 3     WW63253     West Region       Male              Bachelor
# 4     GA49547     East Region       Male  High School or Below
# ...       ...             ...        ...                   ...
# 9052  LA72316     West Region       Male              Bachelor
# 9053  PK87824     West Region     Female               College
# 9054  TD14365     West Region       Male              Bachelor
# 9055  UP19263     West Region       Male               College
# 9056  Y167826     West Region       Male               College
#
#       customer lifetime value        income  monthly premium auto  \
# 0                           0  37710.365172                1000.0
# 1                      697953  37710.365172                  94.0
# ...

# %%
def outlier_mask(customer_data) -> pd.Series:
    q1 = customer_data.quantile(0.25)
    q3 = customer_data.quantile(0.75)
    iqr = q3 - q1
    return ~((customer_data < (q1 - 1.5*iqr)) | (customer_data > (q3 + 1.5*iqr)))

# %%
customer_data.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count             9.057000e+03   9056.000000           9056.000000
# mean              1.772112e+05  47225.403204            110.695782
# std               4.449046e+05  21714.340336            583.958855
# min               0.000000e+00  10037.000000             61.000000
# 25%               0.000000e+00  34336.500000             68.000000
# 50%               0.000000e+00  37710.365172             83.000000
# 75%               0.000000e+00  62280.500000            109.000000
# max               5.816655e+06  99981.000000          35354.000000
#
#        total claim amount
# count         9056.000000
# mean           432.262361
# std            290.021612
# min              0.099007
# 25%            269.523808
# 50%            379.200000
# 75%            547.200000
# max           2893.239678

# %%
marketing_df = pd.read_csv('Data_Marketing_Customer_Analysis_Round3.csv')

# %%
numerical = marketing_df.select_dtypes(include=[np.number])
numerical
# Out:
#        customer_lifetime_value  income  monthly_premium_auto  \
# 0                         4809   48029                    61
# 1                         2228   92260                    64
# 2                        14947   22139                   100
# 3                        22332   49078                    97
# 4                         9025   23675                   117
# ...                        ...     ...                   ...
# 10684                    15563   61541                   253
# 10685                     5259   61146                    65
# 10686                    23893   39837                   201
# 10687                    11971   64195                   158
# 10688                     6857   68942                   101
#
#        months_since_last_claim  months_since_policy_inception  \
# 0                            7                             52
# 1                            3                             26
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# %%
categorical = marketing_df.select_dtypes(include=[np.object])
categorical
# Out:
# /var/folders/8w/ffbmg1l958n0dtswfb_xw04c0000gn/T/ipykernel_7263/115301610.py:1: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical = marketing_df.select_dtypes(include=[np.object])
#             region response  coverage education effective_to_date month  \
# 0          central       no     basic   college           2/18/11   feb
# 1      west region       no     basic   college           1/18/11   jan
# 2             east       no     basic  bachelor           2/10/11   feb
# 3       north west      yes  extended   college           1/11/11   jan
# 4       north west       no   premium  bachelor           1/17/11   jan
# ...            ...      ...       ...       ...               ...   ...
# ...

# %%
fig,axes = plt.subplots(3,3,figsize = (12,10))

sns.histplot(data=numerical["customer_lifetime_value"], ax=axes[0,0])
sns.histplot(data=numerical["income"], ax=axes[0,1])
sns.histplot(data=numerical["monthly_premium_auto"], ax=axes[0,2])
sns.histplot(data=numerical["months_since_last_claim"], ax=axes[1,0])
sns.histplot(data=numerical["months_since_policy_inception"], ax=axes[1,1])
sns.histplot(data=numerical["number_of_open_complaints"], ax=axes[1,2])
sns.histplot(data=numerical["number_of_policies"], ax=axes[2,0])
sns.histplot(data=numerical["total_claim_amount"], ax=axes[2,1])
# Out:
# <AxesSubplot:xlabel='total_claim_amount', ylabel='Count'>

# %%
numerical.hist(figsize=(15,15))
# Out:
# array([[<AxesSubplot:title={'center':'customer_lifetime_value'}>,
#         <AxesSubplot:title={'center':'income'}>,
#         <AxesSubplot:title={'center':'monthly_premium_auto'}>],
#        [<AxesSubplot:title={'center':'months_since_last_claim'}>,
#         <AxesSubplot:title={'center':'months_since_policy_inception'}>,
#         <AxesSubplot:title={'center':'number_of_open_complaints'}>],
#        [<AxesSubplot:title={'center':'number_of_policies'}>,
#         <AxesSubplot:title={'center':'total_claim_amount'}>,
#         <AxesSubplot:>]], dtype=object)

# %%
sns.heatmap(numerical.corr());
